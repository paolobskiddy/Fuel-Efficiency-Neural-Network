# %% [markdown]
# # Predicting Fuel Efficiency Using Neural Networks
# For something different, I designed a model that that performs regressions
# There were alot of models that I experimented with, from LinearRegression, to SVR, to Forest Classifiers, ultimately, Neural networks seem to be the one that works best.
# Since this is my first regression model, I'd probably come back here and check to see what I did differently in the future.

# %% [markdown]
# ### Importing Libraries
# One new thing I did here was use SMOTE; the dataset was too small for my neural network to improve upon, so I had to add more datapoints.

# %%
import pandas as pd
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, InputLayer, BatchNormalization
from tensorflow.keras.regularizers import L2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, OneHotEncoder, OrdinalEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import root_mean_squared_error
from imblearn.over_sampling import RandomOverSampler
import numpy as np
import matplotlib as plt

# %% [markdown]
# ### Importing the dataset

# %%
df = pd.read_csv("car_data.csv")

# %%
df.head()
# Out:
#    city_mpg                        class  combination_mpg  cylinders  \
# 0        25                  midsize car               29        4.0
# 1        26                  midsize car               30        4.0
# 2        25  small sport utility vehicle               27        4.0
# 3        26  small sport utility vehicle               29        4.0
# 4        26  small sport utility vehicle               28        4.0
#
#    displacement drive fuel_type  highway_mpg   make     model transmission  \
# 0           2.5   fwd       gas           36  mazda         6            m
# 1           2.5   fwd       gas           37  mazda         6            a
# 2           2.5   fwd       gas           31  mazda  cx-5 2wd            a
# 3           2.0   fwd       gas           34  mazda  cx-5 2wd            m
# 4           2.0   fwd       gas           32  mazda  cx-5 2wd            a
#
#    year
# 0  2014
# 1  2014
# 2  2014
# 3  2014
# 4  2014

# %% [markdown]
# ### Filing Na values with 0.
# When I did check the data there was one vehicle here that is electrice, so understandably, it's displacement and cylinders are NaN. I've opted to remove this from the dataset for now.

# %%
df = df.fillna(0)
df.isna().sum()
# Out:
# city_mpg           0
# class              0
# combination_mpg    0
# cylinders          0
# displacement       0
# drive              0
# fuel_type          0
# highway_mpg        0
# make               0
# model              0
# transmission       0
# year               0
# dtype: int64

# %% [markdown]
# #### You can see the vehicle here:

# %%
plt.pyplot.hist(df['city_mpg'])
# Out:
# (array([352., 187.,   6.,   3.,   0.,   0.,   0.,   0.,   0.,   2.]),
#  array([ 11. ,  22.5,  34. ,  45.5,  57. ,  68.5,  80. ,  91.5, 103. ,
#         114.5, 126. ]),
#  <BarContainer object of 10 artists>)

# %%
df_clean = df[df['model']!='i-miev']
df_clean
# Out:
#      city_mpg                        class  combination_mpg  cylinders  \
# 0          25                  midsize car               29        4.0
# 1          26                  midsize car               30        4.0
# 2          25  small sport utility vehicle               27        4.0
# 3          26  small sport utility vehicle               29        4.0
# 4          26  small sport utility vehicle               28        4.0
# ..        ...                          ...              ...        ...
# 545        23                  compact car               27        4.0
# 546        21                  midsize car               24        6.0
# 547        21                  midsize car               24        6.0
# 548        17                  midsize car               19        8.0
# 549        17                  midsize car               19        8.0
#
#      displacement drive fuel_type  highway_mpg   make  \
# 0             2.5   fwd       gas           36  mazda
# 1             2.5   fwd       gas           37  mazda
# 2             2.5   fwd       gas           31  mazda
# 3             2.0   fwd       gas           34  mazda
# 4             2.0   fwd       gas           32  mazda
# ..            ...   ...       ...          ...    ...
# 545           2.0   awd       gas           33    bmw
# 546           3.0   rwd       gas           29    bmw
# 547           3.0   awd       gas           29    bmw
# 548           4.4   awd       gas           24    bmw
# 549           4.4   awd       gas           24    bmw
#
#                        model transmission  year
# 0                          6            m  2014
# 1                          6            a  2014
# 2                   cx-5 2wd            a  2014
# 3                   cx-5 2wd            m  2014
# 4                   cx-5 2wd            a  2014
# ..                       ...          ...   ...
# 545   430i xdrive gran coupe            a  2024
# 546          840i gran coupe            a  2024
# 547   840i xdrive gran coupe            a  2024
# 548  m850i xdrive gran coupe            a  2024
# 549     alpina b8 gran coupe            a  2024
#
# [548 rows x 12 columns]

# %% [markdown]
# #### I've created a function that simply fits and transforms the dataset; since the dataset is a mixture of ordinal and categorical values, I took that conversion into consideration.

# %%
enc_ohe = OneHotEncoder(sparse_output=False)
scaler = MinMaxScaler()

def data_transform(train, test, dtype):
    if dtype == "ord":
        X_ord_train = scaler.fit_transform(train)
        X_ord_test = scaler.transform(test)
        return X_ord_train, X_ord_test
    if dtype == "cat":
        X_cat_train = enc_ohe.fit_transform(train)
        X_cat_test =  enc_ohe.transform(test)
        return X_cat_train, X_cat_test

# %% [markdown]
# #### For this case, I use Synthetic Oversampling to increase the dataset size; as previous models performed poorly due to low dataset size.
# I've also gone ahead and selected only 3 categorical features, mostly as the data's dimensionality would increase considerably if I insisted all features be used.

# %%
ordinal = ['city_mpg','cylinders','displacement','highway_mpg']
categorical = ['drive','fuel_type','transmission']

X = df_clean[ordinal + categorical]
y = df_clean['combination_mpg']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42, shuffle=True)
#X_train_samp, y_train_samp = sampler.fit_resample(X_train, y_train)

X_ord_train, X_ord_test = data_transform(X_train[ordinal], X_test[ordinal], "ord")
X_cat_train, X_cat_test = data_transform(X_train[categorical], X_test[categorical], "cat")

X_train_complete = np.concatenate((X_ord_train, X_cat_train), axis=1)
X_test_complete = np.concatenate((X_ord_test, X_cat_test), axis=1)

#X_train_fin, X_val, y_train_fin, y_val = train_test_split(X_train_complete, y_train_samp, test_size=0.20, shuffle=True)

# %%
X_train_complete.shape
# Out:
# (438, 12)

# %% [markdown]
# #### Defining and training the model:

# %%
model_neural =  Sequential()
model_neural.add(InputLayer(shape=[X_train_complete.shape[1],]))
model_neural.add(Dense(64, activation='relu'))
model_neural.add(BatchNormalization())
model_neural.add(Dense(1, activation = 'linear'))
model_neural.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mse', RootMeanSquaredError])

# %%
model_neural.fit(X_train_complete, y_train, epochs=150, validation_split=0.2, shuffle=True)
# Out:
# Epoch 1/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 598.6044 - mse: 598.6044 - root_mean_squared_error: 24.4642 - val_loss: 616.0556 - val_mse: 616.0556 - val_root_mean_squared_error: 24.8205
# Epoch 2/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 577.4162 - mse: 577.4162 - root_mean_squared_error: 24.0285 - val_loss: 610.8129 - val_mse: 610.8129 - val_root_mean_squared_error: 24.7146
# Epoch 3/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 578.7461 - mse: 578.7461 - root_mean_squared_error: 24.0545 - val_loss: 604.9470 - val_mse: 604.9470 - val_root_mean_squared_error: 24.5957
# Epoch 4/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 562.4463 - mse: 562.4463 - root_mean_squared_error: 23.7157 - val_loss: 598.0966 - val_mse: 598.0966 - val_root_mean_squared_error: 24.4560
# Epoch 5/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 548.8640 - mse: 548.8640 - root_mean_squared_error: 23.4272 - val_loss: 589.7587 - val_mse: 589.7587 - val_root_mean_squared_error: 24.2849
# Epoch 6/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 515.8146 - mse: 515.8146 - root_mean_squared_error: 22.7072 - val_loss: 581.3578 - val_mse: 581.3578 - val_root_mean_squared_error: 24.1114
# Epoch 7/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 530.4518 - mse: 530.4518 - root_mean_squared_error: 23.0292 - val_loss: 572.4307 - val_mse: 572.4307 - val_root_mean_squared_error: 23.9255
# Epoch 8/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 506.9035 - mse: 506.9035 - root_mean_squared_error: 22.5117 - val_loss: 562.9739 - val_mse: 562.9739 - val_root_mean_squared_error: 23.7271
# Epoch 9/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 493.0750 - mse: 493.0750 - root_mean_squared_error: 22.2044 - val_loss: 551.7147 - val_mse: 551.7147 - val_root_mean_squared_error: 23.4886
# Epoch 10/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 512.8875 - mse: 512.8875 - root_mean_squared_error: 22.6410 - val_loss: 539.2380 - val_mse: 539.2380 - val_root_mean_squared_error: 23.2215
# Epoch 11/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 472.2109 - mse: 472.2109 - root_mean_squared_error: 21.7300 - val_loss: 524.2568 - val_mse: 524.2568 - val_root_mean_squared_error: 22.8967
# Epoch 12/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 470.6487 - mse: 470.6487 - root_mean_squared_error: 21.6914 - val_loss: 507.5830 - val_mse: 507.5830 - val_root_mean_squared_error: 22.5296
# Epoch 13/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 435.4324 - mse: 435.4324 - root_mean_squared_error: 20.8639 - val_loss: 489.9840 - val_mse: 489.9840 - val_root_mean_squared_error: 22.1356
# Epoch 14/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 423.1194 - mse: 423.1194 - root_mean_squared_error: 20.5688 - val_loss: 471.0996 - val_mse: 471.0996 - val_root_mean_squared_error: 21.7048
# Epoch 15/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 412.5292 - mse: 412.5292 - root_mean_squared_error: 20.3095 - val_loss: 452.2330 - val_mse: 452.2330 - val_root_mean_squared_error: 21.2658
# Epoch 16/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 384.9517 - mse: 384.9517 - root_mean_squared_error: 19.6193 - val_loss: 430.0525 - val_mse: 430.0525 - val_root_mean_squared_error: 20.7377
# Epoch 17/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 357.5952 - mse: 357.5952 - root_mean_squared_error: 18.9074 - val_loss: 406.0044 - val_mse: 406.0044 - val_root_mean_squared_error: 20.1496
# Epoch 18/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 358.2312 - mse: 358.2312 - root_mean_squared_error: 18.9252 - val_loss: 380.5858 - val_mse: 380.5858 - val_root_mean_squared_error: 19.5086
# Epoch 19/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 327.3251 - mse: 327.3251 - root_mean_squared_error: 18.0908 - val_loss: 355.4510 - val_mse: 355.4510 - val_root_mean_squared_error: 18.8534
# Epoch 20/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 291.8534 - mse: 291.8534 - root_mean_squared_error: 17.0780 - val_loss: 327.3869 - val_mse: 327.3869 - val_root_mean_squared_error: 18.0938
# Epoch 21/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 299.1168 - mse: 299.1168 - root_mean_squared_error: 17.2915 - val_loss: 301.6444 - val_mse: 301.6444 - val_root_mean_squared_error: 17.3679
# Epoch 22/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 264.6167 - mse: 264.6167 - root_mean_squared_error: 16.2664 - val_loss: 278.5813 - val_mse: 278.5813 - val_root_mean_squared_error: 16.6908
# Epoch 23/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 242.9886 - mse: 242.9886 - root_mean_squared_error: 15.5756 - val_loss: 255.7231 - val_mse: 255.7231 - val_root_mean_squared_error: 15.9913
# Epoch 24/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 229.3496 - mse: 229.3496 - root_mean_squared_error: 15.1425 - val_loss: 231.3944 - val_mse: 231.3944 - val_root_mean_squared_error: 15.2117
# Epoch 25/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 197.3795 - mse: 197.3795 - root_mean_squared_error: 14.0479 - val_loss: 212.1610 - val_mse: 212.1610 - val_root_mean_squared_error: 14.5657
# Epoch 26/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 177.1131 - mse: 177.1131 - root_mean_squared_error: 13.3063 - val_loss: 191.5651 - val_mse: 191.5651 - val_root_mean_squared_error: 13.8407
# Epoch 27/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 173.4361 - mse: 173.4361 - root_mean_squared_error: 13.1679 - val_loss: 169.7340 - val_mse: 169.7340 - val_root_mean_squared_error: 13.0282
# Epoch 28/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 145.8887 - mse: 145.8887 - root_mean_squared_error: 12.0751 - val_loss: 150.7807 - val_mse: 150.7807 - val_root_mean_squared_error: 12.2793
# Epoch 29/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 126.0374 - mse: 126.0374 - root_mean_squared_error: 11.2199 - val_loss: 134.8573 - val_mse: 134.8573 - val_root_mean_squared_error: 11.6128
# Epoch 30/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 117.0350 - mse: 117.0350 - root_mean_squared_error: 10.8157 - val_loss: 118.4098 - val_mse: 118.4098 - val_root_mean_squared_error: 10.8816
# Epoch 31/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 99.0848 - mse: 99.0848 - root_mean_squared_error: 9.9491 - val_loss: 106.4219 - val_mse: 106.4219 - val_root_mean_squared_error: 10.3161
# Epoch 32/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 90.0720 - mse: 90.0720 - root_mean_squared_error: 9.4894 - val_loss: 90.7104 - val_mse: 90.7104 - val_root_mean_squared_error: 9.5242
# Epoch 33/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 81.3924 - mse: 81.3924 - root_mean_squared_error: 9.0123 - val_loss: 81.3243 - val_mse: 81.3243 - val_root_mean_squared_error: 9.0180
# Epoch 34/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 60.8074 - mse: 60.8074 - root_mean_squared_error: 7.7933 - val_loss: 70.9562 - val_mse: 70.9562 - val_root_mean_squared_error: 8.4236
# Epoch 35/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 54.6623 - mse: 54.6623 - root_mean_squared_error: 7.3909 - val_loss: 60.5360 - val_mse: 60.5360 - val_root_mean_squared_error: 7.7805
# Epoch 36/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 52.7342 - mse: 52.7342 - root_mean_squared_error: 7.2535 - val_loss: 51.7121 - val_mse: 51.7121 - val_root_mean_squared_error: 7.1911
# Epoch 37/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 38.0198 - mse: 38.0198 - root_mean_squared_error: 6.1645 - val_loss: 44.8169 - val_mse: 44.8169 - val_root_mean_squared_error: 6.6945
# Epoch 38/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 33.0990 - mse: 33.0990 - root_mean_squared_error: 5.7432 - val_loss: 37.4024 - val_mse: 37.4024 - val_root_mean_squared_error: 6.1158
# Epoch 39/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 31.1906 - mse: 31.1906 - root_mean_squared_error: 5.5721 - val_loss: 32.1259 - val_mse: 32.1259 - val_root_mean_squared_error: 5.6680
# Epoch 40/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.0073 - mse: 21.0073 - root_mean_squared_error: 4.5751 - val_loss: 26.8308 - val_mse: 26.8308 - val_root_mean_squared_error: 5.1798
# Epoch 41/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.8436 - mse: 16.8436 - root_mean_squared_error: 4.0989 - val_loss: 23.1695 - val_mse: 23.1695 - val_root_mean_squared_error: 4.8135
# Epoch 42/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.5458 - mse: 18.5458 - root_mean_squared_error: 4.2836 - val_loss: 19.2412 - val_mse: 19.2412 - val_root_mean_squared_error: 4.3865
# Epoch 43/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.4796 - mse: 12.4796 - root_mean_squared_error: 3.5277 - val_loss: 15.3841 - val_mse: 15.3841 - val_root_mean_squared_error: 3.9223
# Epoch 44/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.2524 - mse: 8.2524 - root_mean_squared_error: 2.8644 - val_loss: 11.4646 - val_mse: 11.4646 - val_root_mean_squared_error: 3.3859
# Epoch 45/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.7636 - mse: 9.7636 - root_mean_squared_error: 3.0979 - val_loss: 7.9097 - val_mse: 7.9097 - val_root_mean_squared_error: 2.8124
# Epoch 46/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2988 - mse: 5.2988 - root_mean_squared_error: 2.2857 - val_loss: 8.3067 - val_mse: 8.3067 - val_root_mean_squared_error: 2.8821
# Epoch 47/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6801 - mse: 3.6801 - root_mean_squared_error: 1.9103 - val_loss: 6.2685 - val_mse: 6.2685 - val_root_mean_squared_error: 2.5037
# Epoch 48/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.9442 - mse: 3.9442 - root_mean_squared_error: 1.9823 - val_loss: 5.6875 - val_mse: 5.6875 - val_root_mean_squared_error: 2.3849
# Epoch 49/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8889 - mse: 2.8889 - root_mean_squared_error: 1.6971 - val_loss: 3.5046 - val_mse: 3.5046 - val_root_mean_squared_error: 1.8721
# Epoch 50/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1524 - mse: 2.1524 - root_mean_squared_error: 1.4582 - val_loss: 4.6772 - val_mse: 4.6772 - val_root_mean_squared_error: 2.1627
# Epoch 51/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4716 - mse: 2.4716 - root_mean_squared_error: 1.5635 - val_loss: 2.7368 - val_mse: 2.7368 - val_root_mean_squared_error: 1.6543
# Epoch 52/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8354 - mse: 1.8354 - root_mean_squared_error: 1.3456 - val_loss: 1.8969 - val_mse: 1.8969 - val_root_mean_squared_error: 1.3773
# Epoch 53/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5968 - mse: 2.5968 - root_mean_squared_error: 1.5879 - val_loss: 2.2512 - val_mse: 2.2512 - val_root_mean_squared_error: 1.5004
# Epoch 54/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2414 - mse: 1.2414 - root_mean_squared_error: 1.1075 - val_loss: 1.7176 - val_mse: 1.7176 - val_root_mean_squared_error: 1.3106
# Epoch 55/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2869 - mse: 1.2869 - root_mean_squared_error: 1.1284 - val_loss: 1.4772 - val_mse: 1.4772 - val_root_mean_squared_error: 1.2154
# Epoch 56/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3999 - mse: 2.3999 - root_mean_squared_error: 1.5263 - val_loss: 1.8108 - val_mse: 1.8108 - val_root_mean_squared_error: 1.3457
# Epoch 57/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5843 - mse: 0.5843 - root_mean_squared_error: 0.7418 - val_loss: 0.8904 - val_mse: 0.8904 - val_root_mean_squared_error: 0.9436
# Epoch 58/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6032 - mse: 0.6032 - root_mean_squared_error: 0.7484 - val_loss: 0.8188 - val_mse: 0.8188 - val_root_mean_squared_error: 0.9049
# Epoch 59/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1874 - mse: 1.1874 - root_mean_squared_error: 1.0836 - val_loss: 0.6279 - val_mse: 0.6279 - val_root_mean_squared_error: 0.7924
# Epoch 60/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4425 - mse: 1.4425 - root_mean_squared_error: 1.1895 - val_loss: 0.8458 - val_mse: 0.8458 - val_root_mean_squared_error: 0.9197
# Epoch 61/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0199 - mse: 2.0199 - root_mean_squared_error: 1.3978 - val_loss: 0.3849 - val_mse: 0.3849 - val_root_mean_squared_error: 0.6204
# Epoch 62/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7599 - mse: 0.7599 - root_mean_squared_error: 0.8697 - val_loss: 0.3654 - val_mse: 0.3654 - val_root_mean_squared_error: 0.6045
# Epoch 63/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7051 - mse: 0.7051 - root_mean_squared_error: 0.8233 - val_loss: 0.3077 - val_mse: 0.3077 - val_root_mean_squared_error: 0.5547
# Epoch 64/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8827 - mse: 0.8827 - root_mean_squared_error: 0.9366 - val_loss: 0.2991 - val_mse: 0.2991 - val_root_mean_squared_error: 0.5469
# Epoch 65/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2479 - mse: 1.2479 - root_mean_squared_error: 1.0975 - val_loss: 0.2697 - val_mse: 0.2697 - val_root_mean_squared_error: 0.5193
# Epoch 66/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8953 - mse: 0.8953 - root_mean_squared_error: 0.9154 - val_loss: 0.2029 - val_mse: 0.2029 - val_root_mean_squared_error: 0.4505
# Epoch 67/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6831 - mse: 0.6831 - root_mean_squared_error: 0.8241 - val_loss: 0.2792 - val_mse: 0.2792 - val_root_mean_squared_error: 0.5284
# Epoch 68/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9110 - mse: 0.9110 - root_mean_squared_error: 0.9092 - val_loss: 0.2368 - val_mse: 0.2368 - val_root_mean_squared_error: 0.4867
# Epoch 69/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8132 - mse: 0.8132 - root_mean_squared_error: 0.8971 - val_loss: 0.1992 - val_mse: 0.1992 - val_root_mean_squared_error: 0.4463
# Epoch 70/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8922 - mse: 0.8922 - root_mean_squared_error: 0.9400 - val_loss: 0.1706 - val_mse: 0.1706 - val_root_mean_squared_error: 0.4130
# Epoch 71/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7034 - mse: 0.7034 - root_mean_squared_error: 0.8323 - val_loss: 0.2560 - val_mse: 0.2560 - val_root_mean_squared_error: 0.5060
# Epoch 72/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8799 - mse: 0.8799 - root_mean_squared_error: 0.9353 - val_loss: 0.1740 - val_mse: 0.1740 - val_root_mean_squared_error: 0.4172
# Epoch 73/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0739 - mse: 1.0739 - root_mean_squared_error: 1.0244 - val_loss: 0.1861 - val_mse: 0.1861 - val_root_mean_squared_error: 0.4314
# Epoch 74/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6881 - mse: 0.6881 - root_mean_squared_error: 0.8270 - val_loss: 0.1735 - val_mse: 0.1735 - val_root_mean_squared_error: 0.4165
# Epoch 75/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7690 - mse: 0.7690 - root_mean_squared_error: 0.8626 - val_loss: 0.1519 - val_mse: 0.1519 - val_root_mean_squared_error: 0.3898
# Epoch 76/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5933 - mse: 0.5933 - root_mean_squared_error: 0.7634 - val_loss: 0.1904 - val_mse: 0.1904 - val_root_mean_squared_error: 0.4363
# Epoch 77/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9447 - mse: 0.9447 - root_mean_squared_error: 0.9504 - val_loss: 0.2197 - val_mse: 0.2197 - val_root_mean_squared_error: 0.4687
# Epoch 78/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5895 - mse: 1.5895 - root_mean_squared_error: 1.2450 - val_loss: 0.2660 - val_mse: 0.2660 - val_root_mean_squared_error: 0.5157
# Epoch 79/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0830 - mse: 1.0830 - root_mean_squared_error: 1.0048 - val_loss: 0.2574 - val_mse: 0.2574 - val_root_mean_squared_error: 0.5074
# Epoch 80/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0993 - mse: 2.0993 - root_mean_squared_error: 1.4432 - val_loss: 0.1598 - val_mse: 0.1598 - val_root_mean_squared_error: 0.3998
# Epoch 81/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4428 - mse: 0.4428 - root_mean_squared_error: 0.6568 - val_loss: 0.1627 - val_mse: 0.1627 - val_root_mean_squared_error: 0.4033
# Epoch 82/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.9308 - mse: 0.9308 - root_mean_squared_error: 0.9496 - val_loss: 0.1855 - val_mse: 0.1855 - val_root_mean_squared_error: 0.4307
# Epoch 83/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8672 - mse: 0.8672 - root_mean_squared_error: 0.9103 - val_loss: 0.2821 - val_mse: 0.2821 - val_root_mean_squared_error: 0.5311
# Epoch 84/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7586 - mse: 0.7586 - root_mean_squared_error: 0.8591 - val_loss: 0.2120 - val_mse: 0.2120 - val_root_mean_squared_error: 0.4605
# Epoch 85/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6676 - mse: 0.6676 - root_mean_squared_error: 0.7927 - val_loss: 0.1966 - val_mse: 0.1966 - val_root_mean_squared_error: 0.4434
# Epoch 86/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6324 - mse: 1.6324 - root_mean_squared_error: 1.2541 - val_loss: 0.1601 - val_mse: 0.1601 - val_root_mean_squared_error: 0.4001
# Epoch 87/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3564 - mse: 1.3564 - root_mean_squared_error: 1.1593 - val_loss: 0.1782 - val_mse: 0.1782 - val_root_mean_squared_error: 0.4222
# Epoch 88/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6838 - mse: 0.6838 - root_mean_squared_error: 0.8112 - val_loss: 0.1540 - val_mse: 0.1540 - val_root_mean_squared_error: 0.3924
# Epoch 89/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5895 - mse: 1.5895 - root_mean_squared_error: 1.2269 - val_loss: 0.2034 - val_mse: 0.2034 - val_root_mean_squared_error: 0.4510
# Epoch 90/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5809 - mse: 1.5809 - root_mean_squared_error: 1.2334 - val_loss: 0.1694 - val_mse: 0.1694 - val_root_mean_squared_error: 0.4116
# Epoch 91/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3360 - mse: 1.3360 - root_mean_squared_error: 1.1437 - val_loss: 0.1777 - val_mse: 0.1777 - val_root_mean_squared_error: 0.4215
# Epoch 92/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9605 - mse: 0.9605 - root_mean_squared_error: 0.9575 - val_loss: 0.1588 - val_mse: 0.1588 - val_root_mean_squared_error: 0.3985
# Epoch 93/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1240 - mse: 1.1240 - root_mean_squared_error: 1.0506 - val_loss: 0.2044 - val_mse: 0.2044 - val_root_mean_squared_error: 0.4521
# Epoch 94/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8652 - mse: 0.8652 - root_mean_squared_error: 0.9219 - val_loss: 0.1739 - val_mse: 0.1739 - val_root_mean_squared_error: 0.4170
# Epoch 95/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3875 - mse: 1.3875 - root_mean_squared_error: 1.1761 - val_loss: 0.1537 - val_mse: 0.1537 - val_root_mean_squared_error: 0.3921
# Epoch 96/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5727 - mse: 0.5727 - root_mean_squared_error: 0.7511 - val_loss: 0.1835 - val_mse: 0.1835 - val_root_mean_squared_error: 0.4284
# Epoch 97/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7654 - mse: 0.7654 - root_mean_squared_error: 0.8621 - val_loss: 0.1600 - val_mse: 0.1600 - val_root_mean_squared_error: 0.4000
# Epoch 98/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4849 - mse: 0.4849 - root_mean_squared_error: 0.6921 - val_loss: 0.1385 - val_mse: 0.1385 - val_root_mean_squared_error: 0.3722
# Epoch 99/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7547 - mse: 1.7547 - root_mean_squared_error: 1.3043 - val_loss: 0.1704 - val_mse: 0.1704 - val_root_mean_squared_error: 0.4128
# Epoch 100/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0606 - mse: 1.0606 - root_mean_squared_error: 1.0188 - val_loss: 0.1579 - val_mse: 0.1579 - val_root_mean_squared_error: 0.3974
# Epoch 101/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7581 - mse: 0.7581 - root_mean_squared_error: 0.8596 - val_loss: 0.1932 - val_mse: 0.1932 - val_root_mean_squared_error: 0.4395
# Epoch 102/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5869 - mse: 0.5869 - root_mean_squared_error: 0.7641 - val_loss: 0.2628 - val_mse: 0.2628 - val_root_mean_squared_error: 0.5127
# Epoch 103/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9331 - mse: 0.9331 - root_mean_squared_error: 0.9555 - val_loss: 0.1926 - val_mse: 0.1926 - val_root_mean_squared_error: 0.4388
# Epoch 104/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6970 - mse: 0.6970 - root_mean_squared_error: 0.8169 - val_loss: 0.2081 - val_mse: 0.2081 - val_root_mean_squared_error: 0.4562
# Epoch 105/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8230 - mse: 0.8230 - root_mean_squared_error: 0.8967 - val_loss: 0.1669 - val_mse: 0.1669 - val_root_mean_squared_error: 0.4085
# Epoch 106/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3483 - mse: 1.3483 - root_mean_squared_error: 1.1597 - val_loss: 0.2122 - val_mse: 0.2122 - val_root_mean_squared_error: 0.4606
# Epoch 107/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7292 - mse: 0.7292 - root_mean_squared_error: 0.8499 - val_loss: 0.1370 - val_mse: 0.1370 - val_root_mean_squared_error: 0.3701
# Epoch 108/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5139 - mse: 1.5139 - root_mean_squared_error: 1.2234 - val_loss: 0.2185 - val_mse: 0.2185 - val_root_mean_squared_error: 0.4675
# Epoch 109/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4664 - mse: 1.4664 - root_mean_squared_error: 1.1909 - val_loss: 0.1648 - val_mse: 0.1648 - val_root_mean_squared_error: 0.4060
# Epoch 110/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.0565 - mse: 1.0565 - root_mean_squared_error: 1.0155 - val_loss: 0.1763 - val_mse: 0.1763 - val_root_mean_squared_error: 0.4198
# Epoch 111/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1228 - mse: 1.1228 - root_mean_squared_error: 1.0426 - val_loss: 0.2305 - val_mse: 0.2305 - val_root_mean_squared_error: 0.4801
# Epoch 112/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6086 - mse: 0.6086 - root_mean_squared_error: 0.7673 - val_loss: 0.1604 - val_mse: 0.1604 - val_root_mean_squared_error: 0.4004
# Epoch 113/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6801 - mse: 0.6801 - root_mean_squared_error: 0.8165 - val_loss: 0.1992 - val_mse: 0.1992 - val_root_mean_squared_error: 0.4464
# Epoch 114/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6057 - mse: 1.6057 - root_mean_squared_error: 1.2208 - val_loss: 0.1963 - val_mse: 0.1963 - val_root_mean_squared_error: 0.4431
# Epoch 115/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4432 - mse: 0.4432 - root_mean_squared_error: 0.6569 - val_loss: 0.1564 - val_mse: 0.1564 - val_root_mean_squared_error: 0.3955
# Epoch 116/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9202 - mse: 0.9202 - root_mean_squared_error: 0.9346 - val_loss: 0.2443 - val_mse: 0.2443 - val_root_mean_squared_error: 0.4943
# Epoch 117/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3711 - mse: 0.3711 - root_mean_squared_error: 0.6015 - val_loss: 0.1880 - val_mse: 0.1880 - val_root_mean_squared_error: 0.4335
# Epoch 118/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2450 - mse: 1.2450 - root_mean_squared_error: 1.1014 - val_loss: 0.1649 - val_mse: 0.1649 - val_root_mean_squared_error: 0.4061
# Epoch 119/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0066 - mse: 1.0066 - root_mean_squared_error: 0.9932 - val_loss: 0.1806 - val_mse: 0.1806 - val_root_mean_squared_error: 0.4250
# Epoch 120/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7377 - mse: 0.7377 - root_mean_squared_error: 0.8412 - val_loss: 0.1396 - val_mse: 0.1396 - val_root_mean_squared_error: 0.3737
# Epoch 121/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7063 - mse: 0.7063 - root_mean_squared_error: 0.8363 - val_loss: 0.1409 - val_mse: 0.1409 - val_root_mean_squared_error: 0.3753
# Epoch 122/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1741 - mse: 5.1741 - root_mean_squared_error: 2.1530 - val_loss: 0.2623 - val_mse: 0.2623 - val_root_mean_squared_error: 0.5121
# Epoch 123/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6917 - mse: 0.6917 - root_mean_squared_error: 0.8184 - val_loss: 0.2936 - val_mse: 0.2936 - val_root_mean_squared_error: 0.5419
# Epoch 124/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3026 - mse: 1.3026 - root_mean_squared_error: 1.1340 - val_loss: 0.1391 - val_mse: 0.1391 - val_root_mean_squared_error: 0.3730
# Epoch 125/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1330 - mse: 1.1330 - root_mean_squared_error: 1.0462 - val_loss: 0.2088 - val_mse: 0.2088 - val_root_mean_squared_error: 0.4569
# Epoch 126/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7417 - mse: 0.7417 - root_mean_squared_error: 0.8583 - val_loss: 0.2249 - val_mse: 0.2249 - val_root_mean_squared_error: 0.4742
# Epoch 127/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0069 - mse: 1.0069 - root_mean_squared_error: 0.9967 - val_loss: 0.2243 - val_mse: 0.2243 - val_root_mean_squared_error: 0.4736
# Epoch 128/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5668 - mse: 0.5668 - root_mean_squared_error: 0.7472 - val_loss: 0.2065 - val_mse: 0.2065 - val_root_mean_squared_error: 0.4544
# Epoch 129/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7194 - mse: 0.7194 - root_mean_squared_error: 0.8386 - val_loss: 0.2133 - val_mse: 0.2133 - val_root_mean_squared_error: 0.4618
# Epoch 130/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0884 - mse: 1.0884 - root_mean_squared_error: 1.0091 - val_loss: 0.4055 - val_mse: 0.4055 - val_root_mean_squared_error: 0.6368
# Epoch 131/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1615 - mse: 1.1615 - root_mean_squared_error: 1.0717 - val_loss: 0.1748 - val_mse: 0.1748 - val_root_mean_squared_error: 0.4181
# Epoch 132/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5157 - mse: 0.5157 - root_mean_squared_error: 0.7077 - val_loss: 0.1802 - val_mse: 0.1802 - val_root_mean_squared_error: 0.4245
# Epoch 133/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5813 - mse: 0.5813 - root_mean_squared_error: 0.7115 - val_loss: 0.1892 - val_mse: 0.1892 - val_root_mean_squared_error: 0.4350
# Epoch 134/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4312 - mse: 1.4312 - root_mean_squared_error: 1.1934 - val_loss: 0.2093 - val_mse: 0.2093 - val_root_mean_squared_error: 0.4575
# Epoch 135/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2101 - mse: 1.2101 - root_mean_squared_error: 1.0869 - val_loss: 0.4526 - val_mse: 0.4526 - val_root_mean_squared_error: 0.6727
# Epoch 136/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1663 - mse: 1.1663 - root_mean_squared_error: 1.0754 - val_loss: 0.2398 - val_mse: 0.2398 - val_root_mean_squared_error: 0.4897
# Epoch 137/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9188 - mse: 1.9188 - root_mean_squared_error: 1.3648 - val_loss: 0.4628 - val_mse: 0.4628 - val_root_mean_squared_error: 0.6803
# Epoch 138/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7495 - mse: 0.7495 - root_mean_squared_error: 0.8632 - val_loss: 0.1809 - val_mse: 0.1809 - val_root_mean_squared_error: 0.4254
# Epoch 139/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6038 - mse: 0.6038 - root_mean_squared_error: 0.7568 - val_loss: 0.3531 - val_mse: 0.3531 - val_root_mean_squared_error: 0.5942
# Epoch 140/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0515 - mse: 1.0515 - root_mean_squared_error: 1.0203 - val_loss: 0.4786 - val_mse: 0.4786 - val_root_mean_squared_error: 0.6918
# Epoch 141/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6036 - mse: 0.6036 - root_mean_squared_error: 0.7693 - val_loss: 0.1460 - val_mse: 0.1460 - val_root_mean_squared_error: 0.3821
# Epoch 142/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3358 - mse: 2.3358 - root_mean_squared_error: 1.5258 - val_loss: 0.1497 - val_mse: 0.1497 - val_root_mean_squared_error: 0.3869
# Epoch 143/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5561 - mse: 0.5561 - root_mean_squared_error: 0.7437 - val_loss: 0.1411 - val_mse: 0.1411 - val_root_mean_squared_error: 0.3757
# Epoch 144/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5660 - mse: 1.5660 - root_mean_squared_error: 1.2401 - val_loss: 0.1472 - val_mse: 0.1472 - val_root_mean_squared_error: 0.3837
# Epoch 145/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5593 - mse: 1.5593 - root_mean_squared_error: 1.2357 - val_loss: 0.1601 - val_mse: 0.1601 - val_root_mean_squared_error: 0.4001
# Epoch 146/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4469 - mse: 1.4469 - root_mean_squared_error: 1.1820 - val_loss: 0.3324 - val_mse: 0.3324 - val_root_mean_squared_error: 0.5766
# Epoch 147/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8761 - mse: 0.8761 - root_mean_squared_error: 0.9123 - val_loss: 0.1463 - val_mse: 0.1463 - val_root_mean_squared_error: 0.3826
# Epoch 148/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1289 - mse: 1.1289 - root_mean_squared_error: 1.0553 - val_loss: 0.1746 - val_mse: 0.1746 - val_root_mean_squared_error: 0.4178
# Epoch 149/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0581 - mse: 1.0581 - root_mean_squared_error: 1.0200 - val_loss: 0.2330 - val_mse: 0.2330 - val_root_mean_squared_error: 0.4827
# Epoch 150/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5509 - mse: 0.5509 - root_mean_squared_error: 0.7333 - val_loss: 0.1434 - val_mse: 0.1434 - val_root_mean_squared_error: 0.3786

# %% [markdown]
# #### Unfortunately, this is as low as the model will go.

# %%
pred_n = model_neural.predict(X_test_complete)
rmse_n = root_mean_squared_error(y_test, pred_n)
print("\nRMSE: " + str(rmse_n))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
# RMSE: 0.37256860733032227
